# %% [markdown]
# <a href="https://colab.research.google.com/github/sherinrayappan/MICROPLASTIC-DETECTOR-/blob/main/K_means_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('/content/kmeans.xlsx')

# %%
data.head(15)
# Out:
#     srno  height  weight
# 0      1     185      72
# 1      2     170      56
# 2      3     168      60
# 3      4     179      68
# 4      5     182      72
# 5      6     188      77
# 6      7     180      71
# 7      8     180      70
# 8      9     183      84
# 9     10     180      84
# 10    11     168      90

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   srno    11 non-null     int64
#  1   height  11 non-null     int64
#  2   weight  11 non-null     int64
# dtypes: int64(3)
# memory usage: 396.0 bytes

# %%
data.describe()
# Out:
#             srno      height     weight
# count  11.000000   11.000000  11.000000
# mean    6.000000  178.454545  73.090909
# std     3.316625    6.817091  10.222079
# min     1.000000  168.000000  56.000000
# 25%     3.500000  174.500000  69.000000
# 50%     6.000000  180.000000  72.000000
# 75%     8.500000  182.500000  80.500000
# max    11.000000  188.000000  90.000000

# %%
data.drop('srno',axis=1)
# Out:
#     height  weight
# 0      185      72
# 1      170      56
# 2      168      60
# 3      179      68
# 4      182      72
# 5      188      77
# 6      180      71
# 7      180      70
# 8      183      84
# 9      180      84
# 10     168      90

# %%
cor_mat=data.corr()
cor_mat
# Out:
#                 srno        height    weight
# srno    1.000000e+00 -1.068498e-15  0.817042
# height -1.068498e-15  1.000000e+00  0.267699
# weight  8.170416e-01  2.676987e-01  1.000000

# %%
sns.heatmap(data=cor_mat,vmax=1,vmin=0)
plt.show()

# %%
from sklearn.cluster import KMeans
wcss=[]
for i in range(1,11):
  kmeans=KMeans(n_clusters=i,init='k-means++',random_state=42)
  kmeans.fit(data.drop('srno',axis=1))
  wcss.append(kmeans.inertia_)

plt.plot(range(1,11),wcss)
plt.title('the elbow method')
plt.xlabel('number of clusters')
plt.ylabel('wcss')
plt.show()
